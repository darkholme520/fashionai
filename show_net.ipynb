# %%
import caffe
import caffe.draw
from google.protobuf import text_format
from caffe.proto import caffe_pb2
from pylab import imshow
from PIL import Image

#conda install pydotplus
#conda install graphviz
def draw_net_ipynb(netfile):
    net = caffe_pb2.NetParameter()
    text_format.Merge(open(netfile).read(), net)
    pngname = 'tmp.png'
    caffe.draw.draw_net_to_file(net, pngname)
    return Image.open(pngname)

# %%
draw_net_ipynb('/home/gege/dong/fashionai/fashion-landmarks/models/FLD_upper/cascade.prototxt')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=8359x2005 at 0x7F64178B3828>

# %%
draw_net_ipynb('/home/gege/dong/fashionai/fashion-landmarks/models/FLD_upper/stage1.prototxt')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=7971x1962 at 0x7F641798D128>
